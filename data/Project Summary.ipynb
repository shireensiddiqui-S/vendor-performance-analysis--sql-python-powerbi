# %% [markdown]
# ## Exploratory data Analysis Insights
# ### Summary Statistics
#
# ![Screenshot_17-10-2025_62350_localhost.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_17-10-2025_63254_localhost.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **Negative & Zero Values:**
# ### **Gross Profit**: Minimum of -52,002.78, indicating Potential losses due to high cost or heavy discount. This could be due to selling products at lower prices than purchase costs.
#
# ### **Profit Margin:** Has a minimum of -~, which suggests instances where revenue is zero or even lower than the total cost, leading to extreme negative profit margins.
#
# ### **Total Sales Quantity & Sales Dollars:** Some products show zero sales, indicating they were purchased but never sold. These may be slow-mving or obsolete stock, leading to inventory inefficiencies.
#
# ### **Outliers Detected by High Standard Deviations:**
#
# ### **Purchase & Actual Prices:** The maximum values (5,681.81 & 7,499.99) are significantly higher than the mean (24.39 & 35.64), indicating premium prouct offerings.
#
# ### **Freight cost:** Extreme variation from 0.09 to 257,032.07 suggests logestics inefficiencies, bulk shipments, or erratic shipping costs across different products.
#
# ### **Stock Turnover:** Range from 0 to 274.5, suggesting some product sell rapidly while others remains unsold for long periods. A value greater than 1 idicates that sales for a product exceed the purchased quantity due to older stock fulfilling orders.
#
#
# ### **Data Filtering**
# ### To enhance the reliability of the insights, we removed inconsistent data point where:
#    - ### Gross Profit -< 0 (to exclude transactions leading to losses).
#    - ### Profit Margin -< 0 (to ensure analysis focuses on profitable
#      transactions).
#    - ### Total Sales Quantity = 0 (to eliminate inventory that was never  sold).

# %% [markdown]
# ### **Correlation insights**
# ![Screenshot_17-10-2025_72119_localhost.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# - PurchasePrice has weak correlations with TotalSalesDollars(-0.012) and GrossProfit(-0.016), suggesting that price variations do not significantly impact sales revenue or Profit.
# - Strong correlation between total Purchase quantity and total sales quantity(0.999), confirming efficient inventory turnover.
# - Negative correlation between profit margin & total sales price(-0.179) suggests that as sales price increases, margins decrease, possibly due to competitive pricing pressures.
# - StockTurnover has weak negative correlation with both GrossProfit(-0.038) and ProfitMargin(-0.055), indicating that faster turnover does not necessarily result in higher profitability.

# %% [markdown]
# ## **Research Questions & Key Findings**
# ### **1.Brands for Promotional or Pricing Adjustmaents**
# ![Screenshot_17-10-2025_85333_localhost.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #### 198 brands exhibit lower sale but higher profit margins, which could benefit from targeted marketing, promotions, or price optimizations to increase volume without compromising profitability.
#
#
# ![Screenshot_17-10-2025_85756_localhost.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **2. Top Vendors by Sales & Purchase Contribution**
# ### The top 10 vendors contribute 65.69% of total purchases, while the remaining vendors contribute only 34.31%. This over-reliance on a few vendor may introduce risks such as supply chain disruptions, indicating a need for diversification.
#
# ![Screenshot_17-10-2025_9847_localhost.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **3. Impact of Bulk Purchasing on Cost Savings**
# ### Vendor buying in large quantities receive a 72% lower unit cost ($10.78 per unit VS. higher unit costs in smaller orders).
#
# ### Bulk pricing strategies encourage larger orders, increasing total sales while maintaning profitability.
#
# ![Screenshot_17-10-2025_9175_localhost.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **4. Identifying Vendors with low Inventory Turnover**
# ### Total Unsold Inventory Capital: $2.71M
# ### Slow-moving inventory increases storage costs, reduces cash flow efficiency, and affects overall profitability.
# ### Identifying vendors with low inventory turnover enables better stock management, minimizing financial strain.
# ![Screenshot_17-10-2025_92533_localhost.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_17-10-2025_9260_localhost.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **5. Profit Margin Comparison: High vs.Low-Performing Vendors**
# ### Top Vendors' Profit MArgin (95% CI): (30.74%, 31.61%), Mean: 31.17%
# ### Low Vendors' Profit Margin (95% CI): (40.48%, 42.62%), Mean:41.55%
# ### Low-performing vendors maintain higher margins but stuggle with sales volumes, indicating potential pricing inefficiencies or market reach issues.
# ### Actionable Insights:
#   - Top-performing vendors: Optimize profitability by adjusting pricing, reducing operational costs, or offering bundled promotions.
#   - Low-performing vendors: Improve marketing efforts, optimize pricing strategies, and enhance distribution networks.
#
# ![Screenshot_17-10-2025_94340_localhost.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **6. Statistical Validation of Profit Margin Differences**
# ### **Hypothesis Testing:**
# ### Ho(Null Hypothesis): There is no significant difference in the mean profit margins of top-performing vendors.
# ### H1(Alternative Hypothesis): A significant different exists in profit margins between the two vendor groups.
#
#
# ### **Result:** The nul hypothesis is rejected, confirming that the two groups operate under distinctly different profitability models.
#
#
# ### **Implication:** High-margin vendors may benefit from better pricing strategies, while top-selling vendor could focus on cost efficiency.
#
#
# ## **Final Recommendations**
#  - ### Re-evaluate pricing for low-sales, high-margin brands to boost sales volume without sacrificing profitability.
#  - ### Diversify vendor partnership to reduce dependency on a few suppliers and mitigate supply chain risks.
#  - ### Leverage bulk purchasing advantages to maintain competitive pricing while optimizing inventory management.
#  - ### Optimize slow-moving inventory by adjusting purchase quantities, launching clearance sales, or revising storage strategies.
#  - ### Enhance marketing and distribution strategies for low-performing vendors to drive higher sales volumes without compromising profit margins.
#  - ### By implementing these recommendations, the company can achieve sustainable profitability, mitigate risks, and enhance overall operational efficiency.

# %%
print("Hello world
")
